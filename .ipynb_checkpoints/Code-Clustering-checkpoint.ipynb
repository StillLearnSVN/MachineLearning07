# %% [markdown]
# ## Comparative Clustering Analysis: K-Means vs AffinityPropagation

# %% [markdown]
# ## K-means Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data Processing and ML Libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Additional Preprocessing
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

class KMeansClustering:
    def __init__(self, file_path):
        """
        Initialize the K-Means clustering analysis
        
        Parameters:
        file_path (str): Path to the Excel file
        """
        # Download NLTK resources
        # nltk.download('punkt', quiet=True)
        # nltk.download('stopwords', quiet=True)
        
        # Load and preprocess data
        self.load_and_preprocess_data(file_path)
    
    def load_and_preprocess_data(self, file_path):
        """
        Load and preprocess data from Excel file
        """
        # Read Excel sheets
        ib_data = pd.read_excel(file_path, sheet_name='DATA IB')
        ik_data = pd.read_excel(file_path, sheet_name='DATA IK')
        
        # Combine purposes
        ib_data['source'] = 'IB'
        ik_data['source'] = 'IK'
        ib_data['purpose'] = ib_data['desc']
        ik_data['purpose'] = ik_data['tujuan']
        
        # Merge datasets
        self.combined_data = pd.concat([
            ib_data[['purpose', 'source']], 
            ik_data[['purpose', 'source']]
        ], ignore_index=True)
        
        # Remove NaN values
        self.combined_data = self.combined_data.dropna(subset=['purpose'])

        # Preprocess purposes
        self.combined_data['purpose'] = self.combined_data['purpose'].apply(self.advanced_text_preprocessing)

        self.combined_data = self.combined_data.drop_duplicates(subset=['purpose'])
    
    def advanced_text_preprocessing(self, text):
        """
        Advanced text preprocessing
        """
        # Convert to lowercase
        text = str(text).lower()

        # Remove unwanted characters such as `_x000D_` and non-alphanumeric characters
        text = re.sub(r'_x[0-9a-fA-F]{4}_', '', text) # Remove `_x000D_` or similar

        text = re.sub(r'[^a-zA-Z\s]', '', text) # Keep only letters and spaces

        # Remove multiple spaces
        text = re.sub(r'\s+', ' ', text).strip()
        
        # Tokenization
        try:
            tokens = word_tokenize(text)
        except:
            tokens = text.split()
        
        # Remove stopwords
        try:
            stop_words = set(stopwords.words('indonesian'))
        except:
            stop_words = set()
        
        tokens = [token for token in tokens if token not in stop_words]
        
        return ' '.join(tokens)
    
    def feature_extraction(self):
        """
        Extract features from text data
        
        Returns:
        numpy array: Feature matrix
        list: Feature names
        """
        # Preprocess text
        self.combined_data['processed_purpose'] = self.combined_data['purpose'].apply(self.advanced_text_preprocessing)
        
        # Feature extraction using TF-IDF
        vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
        feature_matrix = vectorizer.fit_transform(self.combined_data['processed_purpose'])
        
        # Store feature names for interpretation
        self.feature_names = vectorizer.get_feature_names_out()
        
        return feature_matrix.toarray(), self.feature_names
    
    def perform_kmeans_clustering(self, features, feature_names):
        """
        Perform K-Means clustering with optimization
        
        Parameters:
        features (numpy array): Feature matrix
        feature_names (list): Feature names
        
        Returns:
        dict: Clustering results and insights
        """
        # Dimensionality reduction for visualization
        pca = PCA(n_components=2)
        reduced_features = pca.fit_transform(features)
        
        # Evaluate different numbers of clusters
        max_clusters = min(10, len(features) // 2)  # Limit max clusters
        silhouette_scores = []
        wcss = []
        
        # Reduce computation time by using a smaller range
        cluster_range = range(2, max_clusters + 1)
        
        for n_clusters in cluster_range:
            try:
                kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
                cluster_labels = kmeans.fit_predict(features)
                
                # Calculate silhouette score
                silhouette = silhouette_score(features, cluster_labels)
                silhouette_scores.append(silhouette)
                
                # Calculate WCSS
                wcss.append(kmeans.inertia_)
            except Exception as e:
                print(f"Error with {n_clusters} clusters: {e}")
                silhouette_scores.append(-1)
                wcss.append(None)
        
        # Visualize Silhouette Scores
        plt.figure(figsize=(15, 5))
        
        # Subplot 1: Silhouette Scores
        plt.subplot(121)
        plt.plot(list(cluster_range), silhouette_scores, marker='o', label='Silhouette Score')
        plt.title('K-Means Silhouette Scores')
        plt.xlabel('Number of Clusters')
        plt.ylabel('Silhouette Score')
        plt.legend()
        
        # Subplot 2: Elbow Method (WCSS)
        plt.subplot(122)
        plt.plot(list(cluster_range), wcss, marker='o', label='WCSS')
        plt.title('Elbow Method for Optimal K')
        plt.xlabel('Number of Clusters')
        plt.ylabel('WCSS')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig('kmeans_evaluation/kmeans_evaluation.png')
        plt.close()
        
        # Select best number of clusters (from Silhouette Score)
        best_n_clusters = list(cluster_range)[np.argmax(silhouette_scores)]
        print(f"Best number of clusters (Silhouette Score): {best_n_clusters}")
        
        # Perform clustering with best number of clusters
        kmeans = KMeans(n_clusters=best_n_clusters, random_state=42, n_init=10)
        cluster_labels = kmeans.fit_predict(features)
        
        # Visualization
        plt.figure(figsize=(12, 5))
        
        # Scatter plot of clusters
        plt.subplot(121)
        scatter = plt.scatter(reduced_features[:, 0], reduced_features[:, 1], 
                              c=cluster_labels, cmap='viridis')
        plt.title('K-Means Clustering')
        plt.colorbar(scatter)
        
        # Cluster distribution
        plt.subplot(122)
        cluster_counts = pd.Series(cluster_labels).value_counts()
        cluster_counts.plot(kind='bar')
        plt.title('Cluster Distribution')
        plt.xlabel('Cluster')
        plt.ylabel('Number of Samples')
        plt.tight_layout()
        plt.savefig('kmeans_visualization/kmeans_clustering_visualization.png')
        plt.close()
        
        # Generate business insights
        return self.generate_business_insights(
            features, cluster_labels, feature_names
        )

    
    def generate_business_insights(self, features, cluster_labels, feature_names):
        """
        Generate business insights from clustered data
        """
        # Add cluster labels to dataframe
        self.combined_data['cluster'] = cluster_labels
        
        # Analyze clusters
        cluster_insights = {}
        
        for cluster in np.unique(cluster_labels):
            cluster_data = self.combined_data[self.combined_data['cluster'] == cluster]
            
            # Find top keywords for the cluster
            cluster_features = features[cluster_labels == cluster]
            top_keyword_indices = cluster_features.sum(axis=0).argsort()[::-1][:5]
            top_keywords = [feature_names[i] for i in top_keyword_indices]
            
            cluster_insights[int(cluster)] = {
                'keywords': top_keywords,
                'sample_purposes': cluster_data['purpose'].sample(min(3, len(cluster_data))).tolist(),
                'business_opportunities': self.map_keywords_to_opportunities(top_keywords)
            }
        
        return cluster_insights
    
    def map_keywords_to_opportunities(self, keywords):
        """
        Map keywords to potential business opportunities
        """
        opportunity_mappings = {
            'laptop': ['Computer Repair Shop', 'Laptop Sales and Service', 'Tech Accessory Store'],
            'market': ['Market Research Consultancy', 'Local Business Consulting', 'Research Services'],
            'ibadah': ['Event Management', 'Religious Event Planning', 'Community Event Services'],
            'dinas': ['Government Liaison Services', 'Permit and Documentation Assistance'],
            # 'tua': ['Family Support Services', 'Travel Assistance', 'Family Reunion Planning'],
            'orang tua': ['Family Support Services', 'Travel Assistance', 'Personal Assistance'],
            'rumah': ['Home Services', 'Family Support', 'Travel Accommodation'],
            'berobat': ['Healthcare Consultation', 'Medical Travel Services', 'Health Tourism'],
            'tugas': ['Project Management', 'Consulting Services', 'Academic Support'],
            'proyek': ['Project Management', 'Consulting Services', 'Academic Support'],
            'libur': ['Travel Services', 'Vacation Planning', 'Leisure Consulting'],
            'covid': ['Health Safety Consulting', 'Remote Work Solutions', 'Telemedicine Services'],
            'magang': ['Internship Placement', 'Career Development', 'Professional Training'],
            'gigi' : ['Klinik Gigi Spesialis Ortodonti', 'Produk Perawatan Gigi Tambahan', 'Layanan Konsultasi Online']
        }
        
        opportunities = []
        for keyword in keywords:
            if keyword in opportunity_mappings:
                opportunities.extend(opportunity_mappings[keyword])
            if keyword not in opportunity_mappings:
                opportunities.append("General Business Opportunities")
        
        return list(set(opportunities))

def main():
    # File path
    file_path = 'dataset.xlsx'
    
    # Initialize K-Means clustering analysis
    analysis = KMeansClustering(file_path)
    
    # Feature Extraction
    features, feature_names = analysis.feature_extraction()
    
    # Perform K-Means Clustering
    kmeans_results = analysis.perform_kmeans_clustering(features, feature_names)
    
    # Print Business Insights
    print("\n--- K-Means Clustering Business Insights ---")
    for cluster, cluster_info in kmeans_results.items():
        print(f"\nCluster {cluster}:")
        print(f"Top Keywords: {cluster_info['keywords']}")
        print("Sample Purposes:")
        for purpose in cluster_info['sample_purposes']:
            print(f"- {purpose}")
        print("Potential Business Opportunities:")
        for opportunity in cluster_info['business_opportunities']:
            print(f"- {opportunity}")
    
    # Optional: Save results to a file
    import json
    with open('kmeans_evaluation/kmeans_business_insights.json', 'w') as f:
        json.dump(kmeans_results, f, indent=2)

if __name__ == "__main__":
    main()
# Out:
# Best number of clusters (Silhouette Score): 9
#
# --- K-Means Clustering Business Insights ---
#
# Cluster 0:
# Top Keywords: ['memperbaiki', 'laptop', 'ib', 'mengurus', 'balige']
# Sample Purposes:
# - mengikuti acara adat saur matua oppung
# - melayat ketempat aldi simanjuntak
# - pergi kantor dinas lingkungan hidup menjumpai pegawai terkait wawancara pengumpalan data permohonan izin pelaksanaan kegiatan pkmki merangkap pelengkapan mata kuliah kreativitas inovasi
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 1:
# Top Keywords: ['libur', 'semester', 'natal', 'raya', 'idul']
# Sample Purposes:
# - libur natal pjj semester genap
# - libur semester genap
# - libur nasional
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 2:
# Top Keywords: ['pulang', 'kerumah', 'ib', 'pemilu', 'teman']
# Sample Purposes:
# - pulang ib karna jam kosong
# - pulang ruman
# - pulang kerumah ziarah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 3:
# Top Keywords: ['keluarga', 'bertemu', 'acara', 'rumah', 'merayakan']
# Sample Purposes:
# - libur paskah bertemu keluarga
# - pulang rumah bertemu keluarga libur uas
# - ibadah paskah keluarga
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 4:
# Top Keywords: ['orang', 'tua', 'bertemu', 'rumah', 'membantu']
# Sample Purposes:
# - bertemu orang tua memperbaiki laptop ssd
# - kerumah orang tua berjumpa keluargalibur lebaran
# - bertemu orang tua membeli perlengkapan pakaian sidang
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 5:
# Top Keywords: ['gigi', 'kontrol', 'behel', 'dokter', 'periksa']
# Sample Purposes:
# - izin kontrol gigi
# - kontrol gigi buu
# - pembelian obat kontrol behel
# Potential Business Opportunities:
# - Klinik Gigi Spesialis Ortodonti
# - Produk Perawatan Gigi Tambahan
# - Layanan Konsultasi Online
# - General Business Opportunities
#
# Cluster 6:
# Top Keywords: ['rumah', 'pulang', 'sakit', 'saudara', 'rindu']
# Sample Purposes:
# - pulang rumah pergi kota jaga adik rumah
# - pulang rumah pemilu
# - mudik rumah nenek
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 7:
# Top Keywords: ['requirement', 'proyek', 'pa', 'tugas', 'keperluan']
# Sample Purposes:
# - wawancara proyek smp negeri balige
# - requirement pkm
# - wawancara klien pemilik bramsam kuliner stakeholder tugas proyek
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 8:
# Top Keywords: ['orangtua', 'bertemu', 'rumah', 'pulang', 'keluarga']
# Sample Purposes:
# - berjumpa orangtua keluarga
# - pulang rumah bertemu orangtua saudara
# - proyek berjumpa orangtua
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities

# %% [markdown]
# ## AffinityPropagation Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import AffinityPropagation
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.preprocessing import StandardScaler

import re
import nltk
import ssl
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

# NLTK SSL Handling
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context


class AffinityPropagationClustering:
    def __init__(self, file_path):
        self.load_and_preprocess_data(file_path)

    def load_and_preprocess_data(self, file_path):
        """
        Load and preprocess data from Excel file
        """
        # Read Excel sheets
        ib_data = pd.read_excel(file_path, sheet_name='DATA IB')
        ik_data = pd.read_excel(file_path, sheet_name='DATA IK')
        
        # Combine purposes
        ib_data['source'] = 'IB'
        ik_data['source'] = 'IK'
        ib_data['purpose'] = ib_data['desc']
        ik_data['purpose'] = ik_data['tujuan']
        
        # Merge datasets
        self.combined_data = pd.concat([
            ib_data[['purpose', 'source']], 
            ik_data[['purpose', 'source']]
        ], ignore_index=True)
        
        # Remove NaN values
        self.combined_data = self.combined_data.dropna(subset=['purpose'])

        # Preprocess purposes
        self.combined_data['purpose'] = self.combined_data['purpose'].apply(self.advanced_text_preprocessing)

        self.combined_data = self.combined_data.drop_duplicates(subset=['purpose'])
    
    def advanced_text_preprocessing(self, text):
        """
        Advanced text preprocessing
        """
        # Convert to lowercase
        text = str(text).lower()

        # Remove unwanted characters such as `_x000D_` and non-alphanumeric characters
        text = re.sub(r'_x[0-9a-fA-F]{4}_', '', text) # Remove `_x000D_` or similar

        text = re.sub(r'[^a-zA-Z\s]', '', text) # Keep only letters and spaces

        # Remove multiple spaces
        text = re.sub(r'\s+', ' ', text).strip()
        
        # Tokenization
        try:
            tokens = word_tokenize(text)
        except:
            tokens = text.split()
        
        # Remove stopwords
        try:
            stop_words = set(stopwords.words('indonesian'))
        except:
            stop_words = set()
        
        tokens = [token for token in tokens if token not in stop_words]
        
        return ' '.join(tokens)

    def feature_extraction(self):
        self.combined_data['processed_purpose'] = self.combined_data['purpose'].apply(self.advanced_text_preprocessing)

        vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
        feature_matrix = vectorizer.fit_transform(self.combined_data['processed_purpose'])
        self.feature_names = list(vectorizer.get_feature_names_out())
        return feature_matrix

    def perform_affinity_propagation_clustering(self, features):
        # Scale the features
        scaler = StandardScaler()
        scaled_features = scaler.fit_transform(features.toarray())
    
        # Try different damping parameters and preferences
        damping_values = [0.5, 0.6, 0.7, 0.8, 0.9, 1]
        preference_values = [None, 'median', 'mean']
    
        evaluation_results = []
        plt.figure(figsize=(20, 15))
    
        for i, damping in enumerate(damping_values):
            for j, pref_type in enumerate(preference_values):
                try:
                    # Calculate preference
                    if pref_type == 'median':
                        preference = np.median(cosine_similarity(scaled_features))
                    elif pref_type == 'mean':
                        preference = np.mean(cosine_similarity(scaled_features))
                    else:
                        preference = None
    
                    # Perform Affinity Propagation
                    similarity_matrix = cosine_similarity(scaled_features)
                    similarity_matrix = np.clip(similarity_matrix, 0, 1)
    
                    affinity_prop = AffinityPropagation(
                        damping=damping,
                        preference=preference,
                        affinity='precomputed',
                        random_state=42
                    )
                    cluster_labels = affinity_prop.fit_predict(similarity_matrix)
    
                    # Skip single cluster scenarios
                    unique_clusters = np.unique(cluster_labels)
                    if len(unique_clusters) <= 1:
                        continue
    
                    # Compute evaluation metrics
                    silhouette = silhouette_score(scaled_features, cluster_labels)
                    calinski = calinski_harabasz_score(scaled_features, cluster_labels)
                    davies = davies_bouldin_score(scaled_features, cluster_labels)
    
                    evaluation_results.append({
                        'Damping': damping,
                        'Preference': pref_type,
                        'Num Clusters': len(unique_clusters),
                        'Silhouette Score': silhouette,
                        'Calinski-Harabasz Score': calinski,
                        'Davies-Bouldin Score': davies
                    })
    
                    # Visualization subplot for the evaluation
                    plt.subplot(len(damping_values), len(preference_values),
                                i * len(preference_values) + j + 1)
    
                    # PCA for 2D visualization
                    pca = PCA(n_components=2)
                    reduced_features = pca.fit_transform(scaled_features)
    
                    scatter = plt.scatter(
                        reduced_features[:, 0],
                        reduced_features[:, 1],
                        c=cluster_labels,
                        cmap='viridis'
                    )
                    plt.title(f'Damping: {damping}, Pref: {pref_type}\nClusters: {len(unique_clusters)}')
                    plt.colorbar(scatter)
    
                    # Additional visualization for this configuration
                    plt.figure(figsize=(15, 5))
    
                    # Plot 1: Scatterplot of clusters
                    plt.subplot(131)
                    scatter = plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=cluster_labels, cmap='viridis')
                    plt.title('Affinity Propagation Clustering')
                    plt.colorbar(scatter)
    
                    # Plot 2: Cluster distribution as bar chart
                    plt.subplot(132)
                    cluster_counts = pd.Series(cluster_labels).value_counts()
                    cluster_counts.plot(kind='bar')
                    plt.title('Cluster Distribution')
                    plt.xlabel('Cluster')
                    plt.ylabel('Number of Samples')
    
                    # Plot 3: Scatterplot with exemplar points
                    plt.subplot(133)
                    exemplar_indices = affinity_prop.cluster_centers_indices_
                    plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=cluster_labels, cmap='viridis', alpha=0.7)
                    plt.scatter(reduced_features[exemplar_indices, 0], reduced_features[exemplar_indices, 1],
                                c='red', s=200, marker='x')
                    plt.title('Exemplar Points')
    
                    plt.tight_layout()
                    plt.savefig('af_visualization/affinity_propagation_visualization_{}_{}.png'.format(damping, pref_type))
                    plt.close()
    
                except Exception as e:
                    print(f"Error with damping {damping}, preference {pref_type}: {e}")
    
        plt.tight_layout()
        plt.savefig('af_evaluation/affinity_propagation_evaluation.png')
        plt.close()
    
        # Create and save evaluation results
        evaluation_df = pd.DataFrame(evaluation_results)
        evaluation_df.to_csv('af_evaluation/affinity_propagation_metrics.csv', index=False)
        print("\nEvaluation Metrics:")
        print(evaluation_df)
    
        # Select best configuration based on metrics
        if evaluation_results:
            best_config = max(evaluation_results, key=lambda x: x['Silhouette Score'])
            print("\nBest Configuration:")
            print(best_config)
    
            # Rerun clustering with best configuration
            best_damping = best_config['Damping']
            best_pref_type = best_config['Preference']
    
            # Recalculate preference based on best type
            if best_pref_type == 'median':
                best_preference = np.median(cosine_similarity(scaled_features))
            elif best_pref_type == 'mean':
                best_preference = np.mean(cosine_similarity(scaled_features))
            else:
                best_preference = None
    
            final_affinity_prop = AffinityPropagation(
                damping=best_damping,
                preference=best_preference,
                affinity='precomputed',
                random_state=42
            )
            final_cluster_labels = final_affinity_prop.fit_predict(similarity_matrix)
    
            # Continue with your existing clustering and business insights generation
            return self.generate_business_insights(features, final_cluster_labels, final_affinity_prop.cluster_centers_indices_)
    
        # Fallback to original method if no valid configuration found
        return self.generate_business_insights(features, cluster_labels, affinity_prop.cluster_centers_indices_)


    def generate_business_insights(self, features, cluster_labels, exemplar_indices):
        self.combined_data['cluster'] = cluster_labels
        cluster_insights = {}

        for cluster in np.unique(cluster_labels):
            if cluster == -1:
                continue

            cluster_data = self.combined_data[self.combined_data['cluster'] == cluster]
            cluster_mask = cluster_labels == cluster
            cluster_features = features[cluster_mask]
            top_keyword_indices = np.array(cluster_features.sum(axis=0)).ravel().argsort()[::-1][:5]
            top_keywords = [self.feature_names[i] for i in top_keyword_indices]

            exemplar_index = exemplar_indices[np.where(np.unique(cluster_labels) == cluster)[0][0]]
            exemplar_purpose = self.combined_data.iloc[exemplar_index]['purpose']

            cluster_insights[int(cluster)] = {
                'keywords': top_keywords,
                'sample_purposes': cluster_data['purpose'].sample(min(3, len(cluster_data))).tolist(),
                'business_opportunities': self.map_keywords_to_opportunities(top_keywords),
                'exemplar_purpose': exemplar_purpose,
                'cluster_size': len(cluster_data)
            }

        return cluster_insights

    def map_keywords_to_opportunities(self, keywords):
        opportunity_mappings = {
            'laptop': ['Computer Repair Shop', 'Laptop Sales and Service', 'Tech Accessory Store'],
            'market': ['Market Research Consultancy', 'Local Business Consulting', 'Research Services'],
            'ibadah': ['Event Management', 'Religious Event Planning', 'Community Event Services'],
            'dinas': ['Government Liaison Services', 'Permit and Documentation Assistance'],
            # 'tua': ['Family Support Services', 'Travel Assistance', 'Family Reunion Planning'],
            'orang tua': ['Family Support Services', 'Travel Assistance', 'Personal Assistance'],
            'rumah': ['Home Services', 'Family Support', 'Travel Accommodation'],
            'berobat': ['Healthcare Consultation', 'Medical Travel Services', 'Health Tourism'],
            'tugas': ['Project Management', 'Consulting Services', 'Academic Support'],
            'proyek': ['Project Management', 'Consulting Services', 'Academic Support'],
            'libur': ['Travel Services', 'Vacation Planning', 'Leisure Consulting'],
            'covid': ['Health Safety Consulting', 'Remote Work Solutions', 'Telemedicine Services'],
            'magang': ['Internship Placement', 'Career Development', 'Professional Training'],
            'gigi' : ['Klinik Gigi Spesialis Ortodonti', 'Produk Perawatan Gigi Tambahan', 'Layanan Konsultasi Online']
        }

        opportunities = []
        for keyword in keywords:
            if keyword in opportunity_mappings:
                opportunities.extend(opportunity_mappings[keyword])
            if keyword not in opportunity_mappings:
                opportunities.append("General Business Opportunities")


        return list(set(opportunities))


def main():
    file_path = 'dataset.xlsx'
    try:
        analysis = AffinityPropagationClustering(file_path)
        features = analysis.feature_extraction()
        affinity_results = analysis.perform_affinity_propagation_clustering(features)

        print("\n--- Affinity Propagation Clustering Business Insights ---")
        for cluster, cluster_info in affinity_results.items():
            print(f"\nCluster {cluster} (Size: {cluster_info.get('cluster_size', 'N/A')}):")
            print("Top Keywords:", ", ".join(cluster_info['keywords']))
            print("Sample Purposes:")
            for purpose in cluster_info['sample_purposes']:
                print(f"- {purpose}")
            print("Potential Business Opportunities:")
            for opportunity in cluster_info['business_opportunities']:
                print(f"- {opportunity}")

        with open('af_evaluation/affinity_propagation_business_insights.json', 'w') as f:
            import json
            json.dump(affinity_results, f, indent=2)

    except Exception as e:
        print(f"An error occurred: {e}")


if __name__ == "__main__":
    main()
# Out:
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/ownsys/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# Error with damping 1, preference None: The 'damping' parameter of AffinityPropagation must be a float in the range [0.5, 1.0). Got 1 instead.
# Error with damping 1, preference median: The 'damping' parameter of AffinityPropagation must be a float in the range [0.5, 1.0). Got 1 instead.
# Error with damping 1, preference mean: The 'damping' parameter of AffinityPropagation must be a float in the range [0.5, 1.0). Got 1 instead.
#
# Evaluation Metrics:
#     Damping Preference  Num Clusters  Silhouette Score  \
# 0       0.5       None           636          0.201675
# 1       0.5     median           635          0.199685
# 2       0.5       mean           625          0.202981
# 3       0.6       None           609          0.209196
# 4       0.6     median           606          0.206062
# 5       0.6       mean           609          0.209196
# 6       0.7       None           581          0.226484
# 7       0.7     median           576          0.221958
# 8       0.7       mean           576          0.222628
# 9       0.8       None           576          0.221958
# 10      0.8     median           576          0.221958
# 11      0.8       mean           577          0.221940
# 12      0.9       None           549          0.185027
# 13      0.9     median           549          0.185138
# 14      0.9       mean           554          0.180985
#
#     Calinski-Harabasz Score  Davies-Bouldin Score
# 0                  7.766205              1.458158
# 1                  7.727440              1.458860
# 2                  7.925958              1.462915
# 3                  8.124150              1.462020
# 4                  8.100946              1.463986
# 5                  8.124150              1.462020
# 6                  8.643500              1.459589
# 7                  8.612486              1.462808
# 8                  8.616434              1.463777
# 9                  8.612486              1.462808
# 10                 8.612486              1.462808
# 11                 8.597782              1.462876
# 12                 8.391620              1.520111
# 13                 8.392799              1.519704
# 14                 8.293577              1.521900
#
# Best Configuration:
# {'Damping': 0.7, 'Preference': None, 'Num Clusters': 581, 'Silhouette Score': 0.22648416535549046, 'Calinski-Harabasz Score': 8.64349983081154, 'Davies-Bouldin Score': 1.4595887396211267}
#
# --- Affinity Propagation Clustering Business Insights ---
#
# Cluster 0 (Size: 18):
# Top Keywords: bertemu, tua, orang, pulang, keluarga
# Sample Purposes:
# - bertemu orang tuaa
# - pulang bertemu orang tua
# - pulang rumah bertemu orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 1 (Size: 17):
# Top Keywords: libur, pulang, rumah, ziarah, kamera
# Sample Purposes:
# - libur imblek
# - pulang libur
# - libur lebarann
# Potential Business Opportunities:
# - Home Services
# - Leisure Consulting
# - Family Support
# - Travel Accommodation
# - Vacation Planning
# - General Business Opportunities
# - Travel Services
#
# Cluster 2 (Size: 13):
# Top Keywords: semester, libur, pulang, rumah, ib
# Sample Purposes:
# - libur semester yuhuuuuu
# - ib semester
# - pulang rumah libur semester
# Potential Business Opportunities:
# - Home Services
# - Leisure Consulting
# - Family Support
# - Travel Accommodation
# - Vacation Planning
# - General Business Opportunities
# - Travel Services
#
# Cluster 3 (Size: 7):
# Top Keywords: tugas, proyek, bertemu, requirement, wawancara
# Sample Purposes:
# - requirement tugas proyek
# - pulang kerumah tugas proyek
# - wawancara tugas proyek semester
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 4 (Size: 6):
# Top Keywords: mencegah, upaya, covid, del, penyebaran
# Sample Purposes:
# - libur mencegah penyebaran covid
# - upaya it del mengantisipasi covid
# - bertemu keluarga upaya menghindari virus corona
# Potential Business Opportunities:
# - Telemedicine Services
# - Remote Work Solutions
# - Health Safety Consulting
# - General Business Opportunities
#
# Cluster 5 (Size: 11):
# Top Keywords: bertemu, keluarga, pulang, kerumah, rumah
# Sample Purposes:
# - kerumah bertemu keluarga
# - bertemu keluargaa
# - pulang kerumah bertemu keluarga
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 6 (Size: 18):
# Top Keywords: rindu, rumah, orang, tua, pulang
# Sample Purposes:
# - melepaskan rindu orang rumah
# - pulang rumah rindu orang tua
# - rindu keluarga
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 7 (Size: 18):
# Top Keywords: orangtua, bertemu, pulang, rumah, kerumah
# Sample Purposes:
# - bertemu orangtua keperluan tugas
# - pulang kerumah orangtua
# - pulang bertemu orangtua
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 8 (Size: 3):
# Top Keywords: meninggalkan, asrama, clearance, exit, bertemu
# Sample Purposes:
# - exit clearance meninggalkan asrama bertemu keluarga rumah
# - meninggalkan asrama bertemu keluarga rumah
# - exit clearance meninggalkan asrama bertemu keluarga dirumah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 9 (Size: 4):
# Top Keywords: ganjil, semester, libur, uas, kampung
# Sample Purposes:
# - libur semester ganjil
# - libur uas semester ganjil
# - libur semester ganjil rindu keluarga kampung
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 10 (Size: 6):
# Top Keywords: bermalam, rumah, keluarga, saudara, pulang
# Sample Purposes:
# - bermalam keluarga
# - pulang bermalam
# - bermalam rumah
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 11 (Size: 4):
# Top Keywords: nasional, libur, natal, berlibur, melaksanakan
# Sample Purposes:
# - libur nasional
# - bertemu orangtua libur nasional
# - libur nasional natal
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 12 (Size: 12):
# Top Keywords: acara, keluarga, rumah, bertemu, pulang
# Sample Purposes:
# - meghadiri acara keluarga
# - acara rumah
# - ib acara keluarga
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 13 (Size: 6):
# Top Keywords: nyepi, libur, raya, kerumah, bertemu
# Sample Purposes:
# - libur nyepi bertemu orang tua
# - libur nyepi
# - pulang kerumah bertemu orang tua libur raya nyepi
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 14 (Size: 17):
# Top Keywords: paskah, libur, bertemu, pulang, tua
# Sample Purposes:
# - libur paskah bertemu keluarga
# - bertemu orang tua libur paskah
# - paskah keluarga
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 15 (Size: 18):
# Top Keywords: lebaran, libur, keluarga, bertemu, merayakan
# Sample Purposes:
# - libur lebaran bertemu keluarga
# - libur lebaran rumah orang tua
# - libur lebaran kerumah keluarga
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 16 (Size: 6):
# Top Keywords: proyek, keperluan, pulang, bertemu, keluarga
# Sample Purposes:
# - proyek i
# - keperluan proyek i
# - proyek bertemu keluarga
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 17 (Size: 6):
# Top Keywords: mengikuti, acara, keluarga, pernikahan, izin
# Sample Purposes:
# - izin mengikuti acara keluarga
# - mengikuti acara keluarga
# - mengikuti acara sipaha sada
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 18 (Size: 6):
# Top Keywords: clearance, exit, wisuda, orangtua, pulang
# Sample Purposes:
# - exit clereance
# - exit clearance wisuda
# - pulang exit clearance
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 19 (Size: 6):
# Top Keywords: liburan, semester, bertemu, libur, keluarga
# Sample Purposes:
# - liburan semester libur bertemu keluarga
# - liburan semester bertemu orang tua
# - liburan semester v
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 20 (Size: 10):
# Top Keywords: menemui, tua, orang, orangtua, keluarga
# Sample Purposes:
# - ingi menemui orangtua keluarga
# - menemui orang tua menghindari penyakit
# - urusan keluarga menemui orangtua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 21 (Size: 7):
# Top Keywords: corona, pencegahan, virus, pjj, jarak
# Sample Purposes:
# - pencegahan virus corona
# - upaya pemerintah civitas it del pencegahan virus corona pjj rumah
# - terhindar virus corona
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 22 (Size: 11):
# Top Keywords: uas, libur, bertemu, liburan, pulang
# Sample Purposes:
# - bertemu keluarga libur uas
# - pulang rumah uas
# - ib persiapan natal uas proyek
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 23 (Size: 4):
# Top Keywords: observasi, proyek, smp, data, requirement
# Sample Purposes:
# - observasi proyek
# - observasi proyek smp n balige
# - observasi
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 24 (Size: 6):
# Top Keywords: menghadiri, acara, keluarga, bertemu, tua
# Sample Purposes:
# - bertemu orang tua menghadiri acara keluarga
# - menghadiri acara keluarga bertemu orang tua
# - menghadiri acara keluarga
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 25 (Size: 12):
# Top Keywords: pulang, ziarah, kambuh, kartu, karna
# Sample Purposes:
# - pulang rumahh
# - pulang
# - pulang kerumahpemilu
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 26 (Size: 3):
# Top Keywords: lomba, sumatera, utara, mengikuti, pulang
# Sample Purposes:
# - mengikuti lomba pemilihan putri kebudayaan sumatera utara
# - pulang rumah mengikuti lomba paskah
# - berjumpa orang tua siantar pulang kampung sumatera utara
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 27 (Size: 8):
# Top Keywords: rusak, memperbaiki, laptop, ta, balige
# Sample Purposes:
# - bertemu keluarga requirement ta mengganti laptop rusak laptop bagus
# - memperbaiki laptop rusak balige
# - behel rusak
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 28 (Size: 4):
# Top Keywords: tingkat, perdana, ib, liburan, libur
# Sample Purposes:
# - ib perdana tingkat
# - ib perdana mhasiswa tingkat berjumpa orangtua
# - liburan tingkat
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 29 (Size: 2):
# Top Keywords: doa, kegiatan, acara, keluarga, ziarah
# Sample Purposes:
# - kegiatan doa
# - acara keluarga doa
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 30 (Size: 12):
# Top Keywords: tua, orang, rumah, pulang, libur
# Sample Purposes:
# - keperluan rumah orang tua
# - berpulang rumah orang tua
# - pulang rumah orang tua libur
# Potential Business Opportunities:
# - Home Services
# - Leisure Consulting
# - Travel Accommodation
# - Family Support
# - Vacation Planning
# - General Business Opportunities
# - Travel Services
#
# Cluster 31 (Size: 4):
# Top Keywords: perayaan, natal, paskah, libur, keluarga
# Sample Purposes:
# - perayaan paskah
# - perayaan natal
# - libur perayaan paskah
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 32 (Size: 2):
# Top Keywords: idulfitri, libur, raya, kepergian, kambuh
# Sample Purposes:
# - libur idulfitri
# - libur raya idulfitri
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 33 (Size: 2):
# Top Keywords: software, laptop, memperbaiki, kangen, kamis
# Sample Purposes:
# - memperbaiki laptop software
# - memperbaiki motherboard laptop software windows
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 34 (Size: 3):
# Top Keywords: exitclearance, wisuda, ziarah, kantin, kamis
# Sample Purposes:
# - exitclearance
# - exitclearance strpl
# - exitclearance wisuda
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 35 (Size: 8):
# Top Keywords: pengumpulan, data, proyek, gathering, tugas
# Sample Purposes:
# - pengumpulan data insitut teknologi del
# - pengumpulan data proyek
# - pengumpulan data requirement gathering proyek
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 36 (Size: 13):
# Top Keywords: berobat, bertemu, kerumah, orangtua, pulang
# Sample Purposes:
# - berobat bertemu orang tua
# - bertemu orang tua berobat
# - bertemu orangtua berobat
# Potential Business Opportunities:
# - Medical Travel Services
# - Health Tourism
# - Healthcare Consultation
# - General Business Opportunities
#
# Cluster 37 (Size: 3):
# Top Keywords: keponakan, bertemu, kaka, tercinta, mama
# Sample Purposes:
# - rindu mama kaka abangdan keponakan
# - bertemu keluarga keponakan tercinta
# - bertemu keponakan
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 38 (Size: 5):
# Top Keywords: natal, merayakan, keluarga, libur, bertemu
# Sample Purposes:
# - bertemu keluarga merayakan natal
# - libur semester merayakan natal
# - merayakan natal keluarga
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 39 (Size: 5):
# Top Keywords: kebandara, mengantar, kakak, silangit, adik
# Sample Purposes:
# - mengantar adik kebandara
# - libur buruh bertemu keluarga mengantar kakak kebandara keperantauan
# - mengantar saudara kebandara membantu orang tua menyelesaikan pekerjaan rumah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 40 (Size: 2):
# Top Keywords: renovasi, membantu, rumah, menyelesaikan, kandung
# Sample Purposes:
# - membantu renovasi rumah
# - membantu menyelesaikan renovasi rumah
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 41 (Size: 5):
# Top Keywords: ijin, proyek, demokrasi, requirement, keperluan
# Sample Purposes:
# - ijin duluan pulang sabtu kontrol gigi dokter keperluan ib libur semester
# - ijin requirement smp negeri laguboti kebutuhan proyek
# - ijin pesta demokrasi
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 42 (Size: 3):
# Top Keywords: sehabis, uas, refresing, pulang, seminar
# Sample Purposes:
# - pulang kerumah refresing sehabis uts
# - pulang sehabis uas
# - bertemu orang tua sehabis seminar ta
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 43 (Size: 2):
# Top Keywords: kemedan, barang, menemani, membeli, berobat
# Sample Purposes:
# - membeli barang kemedan
# - pulang kerumah menemani orang tua berobat kemedan
# Potential Business Opportunities:
# - Medical Travel Services
# - Health Tourism
# - Healthcare Consultation
# - General Business Opportunities
#
# Cluster 44 (Size: 3):
# Top Keywords: belanja, barang, medan, keperluan, bandara
# Sample Purposes:
# - belanja barang medan
# - belanja keperluan acara welcoming party himatera sabtu
# - menjemput saudara abang bandara belanja keperluan rumah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 45 (Size: 2):
# Top Keywords: aturan, sesuai, mengembalikan, online, pencegahan
# Sample Purposes:
# - pencegahan covid kuliah online sesuai aturan kampus
# - pulang mengembalikan barang sesuai aturan
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 46 (Size: 8):
# Top Keywords: ta, bertemu, orangtua, keperluan, keluarga
# Sample Purposes:
# - mengurus keperluan ta
# - bertemu keluarga pengerjaan ta
# - ta bertemu orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 47 (Size: 8):
# Top Keywords: natal, semester, libur, liburan, ib
# Sample Purposes:
# - pulang libur semester libur natal
# - liburan semester natal
# - libur natal libur semester
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 48 (Size: 9):
# Top Keywords: urusan, keluarga, tua, orang, mengikuti
# Sample Purposes:
# - urusan rumah
# - mengikuti urusan keluarga
# - urusan keluarga mendadak
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 49 (Size: 4):
# Top Keywords: online, mengisolasi, kuliah, covid, dirumah
# Sample Purposes:
# - mengisolasi didalam rumah menghindari covid pembelajaran online seksama
# - kuliah online
# - mengisolasi dirumah
# Potential Business Opportunities:
# - Telemedicine Services
# - Remote Work Solutions
# - Health Safety Consulting
# - General Business Opportunities
#
# Cluster 50 (Size: 9):
# Top Keywords: merayakan, paskah, pulang, keluarga, rumah
# Sample Purposes:
# - merayakan libur paskah keluarga
# - merayakan paskah keluarga
# - pulang kerumah merayakan paskah
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 51 (Size: 3):
# Top Keywords: ssd, laptop, medan, membeli, memperbaiki
# Sample Purposes:
# - klaim garansi ssd medan
# - membeli ssd keperluan laptop
# - bertemu orang tua memperbaiki laptop ssd
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 52 (Size: 11):
# Top Keywords: jarak, pembelajaran, pjj, covid, virus
# Sample Purposes:
# - pembelajaran jarak terkait virus corona
# - mengikuti pembelajaran jarak
# - pembelajaran jarak pjj rumah
# Potential Business Opportunities:
# - Telemedicine Services
# - Remote Work Solutions
# - Health Safety Consulting
# - General Business Opportunities
#
# Cluster 53 (Size: 4):
# Top Keywords: perlengkapan, pribadi, mengganti, berjumpa, laptop
# Sample Purposes:
# - berjumpa orangtua mengganti perlengkapan keperluan pribadi
# - keperluan perlengkapan kuliah mengurus kartu atm memperbaiki laptop
# - berjumpa orang tua mengganti perlengkapan pribadi
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 54 (Size: 5):
# Top Keywords: daring, dikampus, diperbolehkan, kegiatan, pangkas
# Sample Purposes:
# - mengurus ktp hilang dikampus mengurusnya balige
# - izin pangkas balige diperbolehkan kak yoke pangkas didaerah it del
# - libur semester kegiatan dikampus diperbolehkan kerumah kegiatan mbkm daring rumah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 55 (Size: 18):
# Top Keywords: membantu, tua, orang, rumah, pulang
# Sample Purposes:
# - membantu orangtua jualan
# - rindu rumah membantu orang tua
# - membantu orang tua sawah
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 56 (Size: 11):
# Top Keywords: imlek, libur, merayakan, keluarga, bertemu
# Sample Purposes:
# - liburan imlek
# - merayakan imlek
# - merayakan imlek keluarga
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 57 (Size: 4):
# Top Keywords: melaksanakan, proyek, requirement, pemilu, iii
# Sample Purposes:
# - melaksanakan pemilu
# - melaksanakan proyek
# - melaksanakan requirement matakuliah proyek iii
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 58 (Size: 6):
# Top Keywords: covid, menghindari, pjj, jarak, rumah
# Sample Purposes:
# - bertemu orangtua menghindari virus covid
# - pjj menghindari covid
# - melindungi covid
# Potential Business Opportunities:
# - Home Services
# - Telemedicine Services
# - Family Support
# - Remote Work Solutions
# - Travel Accommodation
# - General Business Opportunities
# - Health Safety Consulting
#
# Cluster 59 (Size: 5):
# Top Keywords: kulit, karantina, mandiri, sakit, periksa
# Sample Purposes:
# - berobat dokter kulit siantar
# - karantina dirumah mengalami sakit kulit derita pengobatan klinik gata gatal sakit kulit kunjung sembuh pagi pengecekan klinik del klinik menyarankan karantina mandiri berdiskusi asarma josua panggabean terbatasnya fasilitas asrama menyarakan pulang kerumah proses pengobatan dipantau orang tua
# - sakit karantina mandiri rumah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 60 (Size: 4):
# Top Keywords: berkusut, buku, salah, tidur, karna
# Sample Purposes:
# - berkusut mengambil buku
# - bertemu orang tua berkusut
# - berkusut
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 61 (Size: 3):
# Top Keywords: biaya, hilang, dokumen, mencetak, hp
# Sample Purposes:
# - mencetak nomor hp hilang pemulihan akun mbanking terblokir memindahkan hp hp hilang lokasi tuju kota balige
# - print dokumen kerumah menghemat biaya mencetak dokumen
# - mengurus ktp hilang kampus mengurus dana beasiswa kerperluan biaya kuliah bank
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 62 (Size: 4):
# Top Keywords: pjj, semester, libur, natal, rumah
# Sample Purposes:
# - libur semester pjj
# - pjj
# - pjj rumah
# Potential Business Opportunities:
# - Home Services
# - Leisure Consulting
# - Family Support
# - Travel Accommodation
# - Vacation Planning
# - General Business Opportunities
# - Travel Services
#
# Cluster 63 (Size: 3):
# Top Keywords: pemulihan, sakit, perpanjangan, kesehatan, ib
# Sample Purposes:
# - perpanjangan ib pemulihan sakit
# - pemulihan sakit
# - pemulihan kesehatan bertemu orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 64 (Size: 5):
# Top Keywords: melengkapi, keperluan, ta, bertemu, tua
# Sample Purposes:
# - pulang kerumah melengkapi barang hilang
# - bertemu orang tua melengkapi artefak ta
# - bertemu orang tua melengkapi keperluan ta
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 65 (Size: 3):
# Top Keywords: tau, orang, makan, ib, asuh
# Sample Purposes:
# - bertemu orang tau
# - ib rumah orang tau asuh
# - izin pulang kerumah ib tau makan dimana uang makan weekend
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 66 (Size: 9):
# Top Keywords: cek, kesehatan, rumah, mata, sakit
# Sample Purposes:
# - cek up
# - cek mata
# - cek kesehatan
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 67 (Size: 10):
# Top Keywords: berjumpa, keluarga, orangtua, proyek, pulang
# Sample Purposes:
# - proyek berjumpa orangtua
# - berjumpa orangtua keluarga
# - ib berjumpa keluarga dirumah
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 68 (Size: 3):
# Top Keywords: kaka, provinsi, kerja, bertemu, pesta
# Sample Purposes:
# - bertemu kaka kerja pulang rumah
# - bertemu keluarga menjemput kaka provinsi
# - menghadiri pesta pernikahan kaka kandung
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 69 (Size: 2):
# Top Keywords: cekup, keluarga, kesehatan, berjumpa, bertemu
# Sample Purposes:
# - berjumpa keluarga cekup kesehatan
# - bertemu keluarga cekup
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 70 (Size: 3):
# Top Keywords: menunggu, wisuda, seminar, persiapan, semester
# Sample Purposes:
# - ib seminar menunggu kepastian
# - persiapan dikuatakan menunggu libur semester
# - exitclearence menunggu wisuda
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 71 (Size: 3):
# Top Keywords: isolasi, corona, virus, perkuliahaan, mencegah
# Sample Purposes:
# - bertemu keluarga isolasi virus corona
# - isolasi mandiri dirumah mencegah penyebaran virus corona perkuliahaan jarak
# - isolasi virus corona
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 72 (Size: 3):
# Top Keywords: perbaikan, laptop, bri, rekening, tugas
# Sample Purposes:
# - perbaikan laptop requirement keperluan tugas
# - acara keluarga kerumah perbaikan rekening bri
# - perbaikan laptop
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Consulting Services
# - Academic Support
# - Computer Repair Shop
# - Project Management
# - General Business Opportunities
# - Tech Accessory Store
#
# Cluster 73 (Size: 4):
# Top Keywords: adat, acara, mengikuti, keluarga, pesta
# Sample Purposes:
# - menemani adik orang tua pergi acara adat
# - mengikuti acara adat keluarga bertemu orang tua
# - mengikuti acara adat saur matua oppung
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 74 (Size: 2):
# Top Keywords: konsultasi, dokter, gigi, sepatu, mengganti
# Sample Purposes:
# - konsultasi dokter gigi mengganti sepatu kuliah rusak
# - konsultasi dokter gigi
# Potential Business Opportunities:
# - Klinik Gigi Spesialis Ortodonti
# - Produk Perawatan Gigi Tambahan
# - Layanan Konsultasi Online
# - General Business Opportunities
#
# Cluster 75 (Size: 4):
# Top Keywords: komponen, laptop, mengganti, rusak, perbaikan
# Sample Purposes:
# - mengganti komponen menservis laptop
# - memperbaiki komponen laptop rusak
# - membeli komponen laptop mengganti komponen laptop rusak
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 76 (Size: 6):
# Top Keywords: ujian, pulang, selesai, rumah, istirahat
# Sample Purposes:
# - pulang ujian selesai ib
# - pulang rumah memasuki minggu ujian
# - istirahat ujian
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 77 (Size: 12):
# Top Keywords: berjumpa, orang, tua, rumah, kerumah
# Sample Purposes:
# - berjumpa orang tua family rumah
# - kerumah orang tua berjumpa keluargalibur lebaran
# - pulang rumah berjumpa orang tua
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 78 (Size: 6):
# Top Keywords: lockdown, kampus, antisipasi, exit, jarak
# Sample Purposes:
# - lockdown kampus antisipasi virus corona
# - lockdown kampus perkuliahan jarak rumah
# - lockdown kampus
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 79 (Size: 4):
# Top Keywords: menjemput, asrama, laptop, medan, menjenguk
# Sample Purposes:
# - menjenguk oppung menjemput atm
# - menjemput laptop
# - asrama menjemput harddisk
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 80 (Size: 5):
# Top Keywords: pindahan, packing, membantu, asrama, ib
# Sample Purposes:
# - membantu orang tua pindahan rumah
# - asrama packing ib
# - asrama packing ib minggu libur lebaran
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 81 (Size: 6):
# Top Keywords: melanjutkan, pertanian, dinas, pengumpulan, data
# Sample Purposes:
# - melanjutkan mengurus rekening kip kuliah
# - melanjutkan pengumpulan data tugas dinas pertanian toba
# - melanjutkan liburan
# Potential Business Opportunities:
# - Permit and Documentation Assistance
# - Government Liaison Services
# - General Business Opportunities
#
# Cluster 82 (Size: 5):
# Top Keywords: mahasiswa, kamera, orangtua, bertemu, program
# Sample Purposes:
# - menyelesaikan exit clearance mahasiswa tingkat melaksanakan wisuda september
# - pengadaan kamera perbaikan kamera pembelian kamera badan eksekutif mahasiswa periode
# - bertemu mitra keperluan pkm program kreativitas mahasiswa
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 83 (Size: 7):
# Top Keywords: adha, idul, libur, rumah, raya
# Sample Purposes:
# - libur idul adha
# - libur idul adha bertemu orang tua
# - liburan idul adha
# Potential Business Opportunities:
# - Home Services
# - Leisure Consulting
# - Family Support
# - Travel Accommodation
# - Vacation Planning
# - General Business Opportunities
# - Travel Services
#
# Cluster 84 (Size: 10):
# Top Keywords: perdana, ib, bertemu, tua, orang
# Sample Purposes:
# - ib perdana
# - bertemu orang tua ib perdana
# - bertemu keluarga ib perdana
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 85 (Size: 3):
# Top Keywords: mencari, lokasi, observasi, ta, proyek
# Sample Purposes:
# - observasi lokasi proyek
# - mencari ketenangan
# - mencari datasurvey lokasi keperluan ta
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 86 (Size: 4):
# Top Keywords: anggota, keluarga, meninggal, kandung, menjenguk
# Sample Purposes:
# - martumpol anggota keluarga kandungkakak kandung
# - menjenguk anggota keluarga sakit
# - acara keluarga mengantar anggota keluarga bandara silangit
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 87 (Size: 9):
# Top Keywords: fitri, raya, idul, libur, melaksanakan
# Sample Purposes:
# - libur raya idul fitri h
# - ib libur raya idul fitri
# - raya idul fitri
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 88 (Size: 16):
# Top Keywords: liburan, keluarga, paskah, kerumah, rumah
# Sample Purposes:
# - liburan paskah berziarah
# - liburan keluarga
# - liburan
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 89 (Size: 6):
# Top Keywords: ketemu, keluarga, burju, mama, perdana
# Sample Purposes:
# - ketemu mama
# - ketemu emak burju
# - ketemu orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 90 (Size: 2):
# Top Keywords: keluargaib, perdana, berjumpa, bertemu, karantina
# Sample Purposes:
# - bertemu keluargaib perdana
# - berjumpa keluargaib perdana
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 91 (Size: 2):
# Top Keywords: si, siantar, wisuda, kandung, kakak
# Sample Purposes:
# - bertemu keluarga si siantar
# - pulang kerumah merayakan wisuda kakak kandung si
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 92 (Size: 7):
# Top Keywords: menukar, pakaian, barang, bertemu, mengganti
# Sample Purposes:
# - menukar pakaian keperluan
# - membeli pakaian
# - menukar barang rumah bertemu orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 93 (Size: 3):
# Top Keywords: pelaksanaan, pa, ta, testing, user
# Sample Purposes:
# - pulang kerumah pelaksanaan uat ta
# - pelaksanaan user testing until pa
# - requirement gathering smpn laguboti rangka pelaksanaan pa
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 94 (Size: 2):
# Top Keywords: menyambut, natal, keluarga, berkumpul, merayakan
# Sample Purposes:
# - merayakan natal menyambut keluarga
# - berkumpul keluarga menyambut natal
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 95 (Size: 4):
# Top Keywords: bca, atm, kartu, mengambil, mendaftarkan
# Sample Purposes:
# - memperbaiki handphone rusak mengambil kartu atm bca
# - mengambil kartu atm bca periksa mata
# - mendaftarkan rekening bca
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 96 (Size: 2):
# Top Keywords: onboarding, ziarah, kamera, kartu, karna
# Sample Purposes:
# - onboarding onsite
# - onboarding work arrangements
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 97 (Size: 6):
# Top Keywords: corona, virus, penyebaran, menghindari, terkena
# Sample Purposes:
# - menghindari penyebaran virus corona
# - menghindari terkena virus corona
# - menghindari penyebaran virus corona pjj
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 98 (Size: 7):
# Top Keywords: pengerjaan, proyek, tugas, istirahat, gathering
# Sample Purposes:
# - requirement gathering pengerjaan proyek
# - pengerjaan tugas pa
# - istirahat pengerjaan proyek
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 99 (Size: 3):
# Top Keywords: mati, memperbaiki, laptop, jam, september
# Sample Purposes:
# - memperbaiki laptop laptop mati hidup berulang kali rabu september malam jam kolab
# - memperbaiki jam mati
# - memperbaiki laptop cursornya bergerak layarnya terkadang tibatiba mati
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 100 (Size: 4):
# Top Keywords: mengalami, kunjung, sembuh, berobat, seminggu
# Sample Purposes:
# - bertemu orang tua melepas kejenuhan hidup kampus it del mengalami asrama lantai
# - pergi berobat seminggu batuk sesak dada kunjung sembuh berobat klinik
# - checkup rumah sakit balige orangtua mengalami demam turun mengigil seminggu surat sakit klinik izin keasramaan
# Potential Business Opportunities:
# - Medical Travel Services
# - Health Tourism
# - Healthcare Consultation
# - General Business Opportunities
#
# Cluster 101 (Size: 5):
# Top Keywords: merawat, sakit, membantu, orangtua, menjaga
# Sample Purposes:
# - membantu merawat orangtua sakit rumah sakit
# - membantu merawat orang tua sakit
# - menjaga merawat oppung sakit
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 102 (Size: 4):
# Top Keywords: syukuran, sidi, acara, mengikuti, keluarga
# Sample Purposes:
# - acara keluarga sidi
# - mengikuti acara syukuran dirumah
# - menghadiri acara syukuran sidi adik
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 103 (Size: 4):
# Top Keywords: keakraban, alumni, malam, makrab, sma
# Sample Purposes:
# - pa makrab alumni
# - malam keakraban alumni
# - malam keakraban
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 104 (Size: 2):
# Top Keywords: asuh, bareng, tua, orang, ibadah
# Sample Purposes:
# - ibadah bareng orang tua asuh
# - orang tua asuh ibada bareng orang tua asuh
# Potential Business Opportunities:
# - Religious Event Planning
# - Event Management
# - Community Event Services
# - General Business Opportunities
#
# Cluster 105 (Size: 2):
# Top Keywords: keruma, opung, asuh, tua, orang
# Sample Purposes:
# - keruma orang tua asuh
# - keruma opung
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 106 (Size: 2):
# Top Keywords: asu, tua, orang, rumah, berlibur
# Sample Purposes:
# - berlibur rumah orang tua asu
# - rumah orang tua asu
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 107 (Size: 33):
# Top Keywords: selesaii, ziarah, kambuh, kartu, karna
# Sample Purposes:
# - sunset
# - jibega
# - selesaii
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 108 (Size: 14):
# Top Keywords: asuh, tua, orang, bermalam, rumah
# Sample Purposes:
# - libur lebaran rumah orang tua asuh
# - berkunjung rumah orang tua asuh
# - rumah orang tua asuh
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 109 (Size: 2):
# Top Keywords: merdeka, kampus, magang, belajar, mbkm
# Sample Purposes:
# - magang kampus merdeka
# - merdeka belajar kampus merdeka mbkm
# Potential Business Opportunities:
# - Career Development
# - Internship Placement
# - Professional Training
# - General Business Opportunities
#
# Cluster 110 (Size: 3):
# Top Keywords: mbkn, tolikara, kabupaten, kerja, kangen
# Sample Purposes:
# - recana kerja peratek mbkn tolikara
# - mbkn
# - pklmagang kabupaten tolikara
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 111 (Size: 5):
# Top Keywords: abang, liburan, mengikuti, wisuda, berjumpa
# Sample Purposes:
# - pulang rumah abang
# - abang liburansaya liburan
# - merayakan wisuda abang
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 112 (Size: 6):
# Top Keywords: kegiatan, keluarga, mengikuti, rumah, pulang
# Sample Purposes:
# - kegiatan retret
# - pulang rumah mengikuti kegiatan dipersiapkan
# - mengikuti kegiatan rumah keluarga
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 113 (Size: 3):
# Top Keywords: praktek, kerja, mbkm, ziarah, kangen
# Sample Purposes:
# - mbkm kerja praktek
# - kerja praktek mbkm
# - kerja praktek
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 114 (Size: 8):
# Top Keywords: mbkm, libur, semester, liburan, keperluan
# Sample Purposes:
# - keperluan mbkm
# - libur semester mbkm
# - liburan mbkm
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 115 (Size: 5):
# Top Keywords: papua, mbkm, tolikara, berangkat, kabupaten
# Sample Purposes:
# - izin keperluhan mbkm provinsi papua pengununga kabupaten tolikara
# - berangkat papua kp mbkm
# - izin berangkat papua tolikara magang mbkm
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 116 (Size: 3):
# Top Keywords: angkat, tua, orang, bermalam, liburan
# Sample Purposes:
# - inzin bermalam orang tua angkat
# - izin bermalam orang tua angkat
# - liburan keluarga orang tua angkat
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 117 (Size: 2):
# Top Keywords: praktik, kerja, mbkm, semester, libur
# Sample Purposes:
# - kerja praktik mbkm
# - libur semester kerja praktik
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 118 (Size: 6):
# Top Keywords: melayani, gereja, minggu, musik, terapi
# Sample Purposes:
# - melayani minggu gereja
# - pertemuan mitra tarutung bertemu keluarga terapi melayani gereja balige
# - pulang rumah orangtua melayani gereja
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 119 (Size: 4):
# Top Keywords: bou, rumah, mengunjungi, balige, kamis
# Sample Purposes:
# - rumah bou
# - mengunjungi rumah bou
# - rumah bou balige
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 120 (Size: 3):
# Top Keywords: jahit, wisuda, keperluan, tukang, pakaian
# Sample Purposes:
# - menjemput pakaian tarutung selesai jahit keperluan magang
# - jahit kebaya wisuda
# - keperluan memperbaiki celana adik angkatan tukang jahit
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 121 (Size: 9):
# Top Keywords: refreshing, ta, seminar, uts, teman
# Sample Purposes:
# - refreshing seminar
# - refreshing ta kerumah keluarga
# - bermalam rumah teman refreshing
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 122 (Size: 11):
# Top Keywords: pemilihan, presiden, tarutung, pemilu, laguboti
# Sample Purposes:
# - libur pemilihan
# - pemilihan tarutung
# - pemilihan umun
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 123 (Size: 7):
# Top Keywords: tanggal, merah, libur, pulang, rangka
# Sample Purposes:
# - pulang rumah tanggal merah
# - pulang kerumah rangka libur tanggal merah
# - pulang rumah rangka tanggal merah
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 124 (Size: 3):
# Top Keywords: tunangan, perempuan, sidi, abang, kandung
# Sample Purposes:
# - tunangan abang kandung
# - adik perempuan sidi
# - acara tunangan saudara perempuan
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 125 (Size: 6):
# Top Keywords: jumat, agung, libur, paskah, merayakan
# Sample Purposes:
# - libur jumat agungpaskah
# - libur jumat agung paskah
# - jumat agung
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 126 (Size: 8):
# Top Keywords: fitri, idul, libur, menjalani, lebaran
# Sample Purposes:
# - libur idul fitri rindu mama
# - menjalani libur idul fitri keluarga
# - libur idul fitri hijriah
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 127 (Size: 4):
# Top Keywords: al, kenaikan, isa, libur, wafat
# Sample Purposes:
# - libur kenaikan isa al
# - libur kenaikan al
# - pulang kerumah menghadiri acara wafat isa al
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 128 (Size: 6):
# Top Keywords: gasal, semester, libur, natal, berlibur
# Sample Purposes:
# - libur semester gasal libur natal
# - berlibur semester gasal
# - libur natal libur libur semester gasal
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 129 (Size: 1):
# Top Keywords: mraj, isra, imlek, libur, ziarah
# Sample Purposes:
# - libur imlek isra mraj
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 130 (Size: 3):
# Top Keywords: pasca, penang, malaysia, mendampingi, konsultasi
# Sample Purposes:
# - mendampingi orangtua medical checkup konsultasi lanjutan pascaoperasi penang malaysia
# - wawancara hamil pasca melahirkan disekitar laguboti keperluan pengumpulan data requirement
# - pulang rumah orangtua mendampingi orangtua medical checkup konsultasi pasca operasi penang malaysia
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 131 (Size: 7):
# Top Keywords: kampung, pulang, merayakan, paskah, bertemu
# Sample Purposes:
# - pulang bertemu orangtua kampung
# - kampung membantu orang tua
# - pulang kampung
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 132 (Size: 10):
# Top Keywords: oppung, kerumah, rumah, menjenguk, berkunjung
# Sample Purposes:
# - kerumah oppung indah
# - pulang kerumah oppung
# - perkunjung rumah oppung
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 133 (Size: 2):
# Top Keywords: memperingati, paskah, libur, keluarga, kamis
# Sample Purposes:
# - libur memperingati paskah
# - memperingati paskah keluarga
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 134 (Size: 7):
# Top Keywords: berkumpul, keluarga, libur, orangtua, rumah
# Sample Purposes:
# - libur semester berkumpul keluarga
# - berkumpul keluarga acara ulang
# - libur paskah berkumpul keluarga tercinta
# Potential Business Opportunities:
# - Home Services
# - Leisure Consulting
# - Family Support
# - Travel Accommodation
# - Vacation Planning
# - General Business Opportunities
# - Travel Services
#
# Cluster 135 (Size: 5):
# Top Keywords: kerumah, tua, orang, pulang, bertemu
# Sample Purposes:
# - pulang kerumah bertemu orang tua
# - pulang kerumah orang tua libur
# - pulang kerumah orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 136 (Size: 3):
# Top Keywords: mengujungi, tua, orang, ta, orangtua
# Sample Purposes:
# - mengujungi orang tua ta
# - mengujungi orangtua
# - mengujungi orang tua
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 137 (Size: 2):
# Top Keywords: camp, summer, semester, libur, mbkm
# Sample Purposes:
# - summer camp libur semester
# - libur semester summer camp mbkm
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 138 (Size: 10):
# Top Keywords: magang, libur, semester, pulang, mbkm
# Sample Purposes:
# - pulang magang
# - pulang rumah magang
# - liburan magang
# Potential Business Opportunities:
# - Leisure Consulting
# - Internship Placement
# - Vacation Planning
# - Professional Training
# - General Business Opportunities
# - Career Development
# - Travel Services
#
# Cluster 139 (Size: 3):
# Top Keywords: weekend, pulang, rumah, healing, ziarah
# Sample Purposes:
# - pulang rumah weekend
# - weekend
# - pulang rumah healing weekend
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 140 (Size: 2):
# Top Keywords: exchange, china, agustus, youth, passport
# Sample Purposes:
# - mengurus pembuatan passport kegiatan indonesia china youth exchange program kanim siantar
# - mengikuti indonesiachina youth exchange dilaksanakan fuzhou china agustus agustus
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 141 (Size: 4):
# Top Keywords: home, ziarah, kawat, kasih, kartu
# Sample Purposes:
# - back to home
# - walking back home
# - go home
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 142 (Size: 8):
# Top Keywords: pergi, rumah, dokter, gigi, opung
# Sample Purposes:
# - pergi rumah orang tua
# - pergi dokter gigi balige
# - pergi kerumah keluarga
# Potential Business Opportunities:
# - Home Services
# - Produk Perawatan Gigi Tambahan
# - Travel Accommodation
# - Family Support
# - Layanan Konsultasi Online
# - General Business Opportunities
# - Klinik Gigi Spesialis Ortodonti
#
# Cluster 143 (Size: 10):
# Top Keywords: pernikahan, menghadiri, kakak, kandung, acara
# Sample Purposes:
# - menghadiri pernikahan saudara
# - menghadiri acara pernikahan kakak
# - menghadiri pesta pernikahan kakak kandung
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 144 (Size: 13):
# Top Keywords: kerumah, pulang, keluarga, libur, keperluan
# Sample Purposes:
# - pulang kerumah
# - pulak kerumah
# - pulanga kerumah keluarga
# Potential Business Opportunities:
# - Travel Services
# - Leisure Consulting
# - Vacation Planning
# - General Business Opportunities
#
# Cluster 145 (Size: 3):
# Top Keywords: tournament, tarutung, mengikuti, orangtua, acara
# Sample Purposes:
# - mengikuti tournament tarutung
# - pulang rumah mengikuti tournament futsal
# - acara keluarga tarutung bertemu orangtua
# Potential Business Opportunities:
# ...
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 533 (Size: 2):
# Top Keywords: kepentingan, keluarga, uts, selesai, bermalam
# Sample Purposes:
# - kepentingan keluarga pulang izin bermalam uts selesai
# - kepentingan keluarga
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 534 (Size: 3):
# Top Keywords: himatera, miss, survey, pemesanan, dilangsungkan
# Sample Purposes:
# - berhubung ketua divisi humas himpunan himatera sabtu dilangsungkan kegiatan welcoming party himatera jumat oktober uts trpl selesai survey lokasi pemesanan miss mengizinkannya terimakasih miss
# - berhubung wakil ketua divisi hubungan masyarakat himpunan teknologi rekayasa perangkat lunak sabtu dilangsungkan kegiatan welcoming party himatera jumat oktober uts trpl selesai survey lokasi pemesanan bapakibu mengizinkannya terimakasih pakbu
# - berhubung wakil ketua himpunan himatera sabtu dilangsungkan kegiatan welcoming party himatera jumat oktober uts trpl selesai survey lokasi pemesanan miss mengizinkannya terimakasih miss
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 535 (Size: 8):
# Top Keywords: medan, berobat, keluarga, ib, lebaran
# Sample Purposes:
# - keperluan membeli barang medan
# - acara keluarga medan
# - medan
# Potential Business Opportunities:
# - Medical Travel Services
# - Health Tourism
# - Healthcare Consultation
# - General Business Opportunities
#
# Cluster 536 (Size: 4):
# Top Keywords: patah, kacamata, memperbaiki, dah, kontrol
# Sample Purposes:
# - memperbaiki kacamata patah
# - memperbaiki kacamata patah dibalige
# - balige memperbaiki kacamata patah dah ujian
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 537 (Size: 2):
# Top Keywords: jam, perjalanan, mitra, requirement, post
# Sample Purposes:
# - keperlian requirement pa jam selesai makan siang kantin post jam perjalanan soposurung mitra pasar laguboti persiapan acara fho balige macet jam bertemu mitra wawancara observasi memperhatikan requirement bisnis umkm perjalanan it del
# - wawancara pa keperluan requirement pa jam selesai makan siang kantin post jam perjalanan soposurung mitra pasar laguboti persiapan acara fho balige macet jam bertemu mitra wawancara observasi memperhatikan requirement bisnis umkm perjalanan it del
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 538 (Size: 6):
# Top Keywords: kacamata, memperbaiki, periksa, mata, mengurus
# Sample Purposes:
# - memperbaiki kacamata belige
# - memperbaiki kacamata
# - periksa mata memperbaiki kacamata
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 539 (Size: 3):
# Top Keywords: berpangkas, kemahasiswaan, barang, laguboti, membeli
# Sample Purposes:
# - mengurus mengambil atm bank bni beasiswa instruksi kemahasiswaan diambil minggu dihari jam mandiri dosen kegiatan
# - membeli barang laguboti berpangkas
# - izin berpangkas peringatkan kemahasiswaan
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 540 (Size: 5):
# Top Keywords: maaf, request, tanggal, pakbu, pengganti
# Sample Purposes:
# - bertemu orangtua panitia pengganti terlambat request ib
# - libur lebaran minal aidzin walfa idzin mohon maaf lahir batin
# - keperluan requirement gathering maaf pakbu ulang request salah input jam
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 541 (Size: 4):
# Top Keywords: nya, miss, rusak, lcd, celana
# Sample Purposes:
# - menukar celana kuliah rusak kancing nya
# - izin miss dipercepat kembalinya mengambil kacamata nya miss
# - perbaiki behel lepas bracet nya makan ayam goreng kantin
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 542 (Size: 5):
# Top Keywords: angkutan, mempercepat, malam, kepulangan, medan
# Sample Purposes:
# - izin bermalam dimedan malam angkutan
# - mempercepat kepulangan ib mengejar angkutan perkuliahan kelas selesai
# - mempercepat kepergian ib sulit angkutan orang pulang kampung berpaskah keluarga menyelesaikan perkuliahan week ibadah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 543 (Size: 7):
# Top Keywords: uts, selesai, pulang, keluarga, rumah
# Sample Purposes:
# - pulang rumah ib uts
# - pulang uts selesai
# - urusan keluarga selesai uts
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 544 (Size: 4):
# Top Keywords: pameran, pa, perlengkapan, menjemput, seminar
# Sample Purposes:
# - menjemput perlengkapan pameran pa ii
# - menjemput perlengkapan pameran
# - libur semester selesai pameran pa
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 545 (Size: 4):
# Top Keywords: konter, diperbaiki, janji, hp, mengambil
# Sample Purposes:
# - mengambil laptop diperbaiki
# - memperbaiki hp konter balige
# - mengikuti acara ikat janji kakak kandung
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 546 (Size: 5):
# Top Keywords: ii, requirement, pengerjaan, pa, keperluan
# Sample Purposes:
# - requirement keperluan pa ii
# - requirement kebutuhan pengerjaan pa ii
# - libur semester ii
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 547 (Size: 2):
# Top Keywords: membereskan, berfungsi, asrama, barang, bni
# Sample Purposes:
# - membereskan karty atm bni berfungsi
# - asrama barang dibawa pulang rmh membereskan kamar ditinggal bersih ib
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 548 (Size: 3):
# Top Keywords: kopi, penyakit, analysis, sekitaran, tanaman
# Sample Purposes:
# - requirement mengidentifikasi jenis penyakit tanaman daun kopi keperluan project mata kuliah pembelajaran mesin
# - requirements analysis penyakit tanaman kopi sekitaran porsea laguboti balige
# - requierements analysis penyakit kopi sekitaran porsealagubotibalige
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 549 (Size: 3):
# Top Keywords: telat, kepulangan, mempercepat, ib, control
# Sample Purposes:
# - mempercepat kepulangan ib telat rumah
# - control behel telat
# - mempercepat kepulangan ib telat dirumah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 550 (Size: 8):
# Top Keywords: machine, learning, project, requirement, data
# Sample Purposes:
# - melengkapi data proyek machine learning
# - wawancara mengumpulkan dataset daun jagung keperluan project machine learning izin ta dosen machine learning
# - requirement gathering project machine learning
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 551 (Size: 3):
# Top Keywords: wawancara, ownernya, alasan, perjalanan, pa
# Sample Purposes:
# - wawancara pa alasan pulang jam rumah ownernya
# - wawancara pa i desa sirongit laguboti alasan jam perjalanan rumah ownernya
# - wawancara pa i estimasi persiapan mencari angkutan perjalanan tujuan persiapan wawancara pelaksanaan wawancara pulang
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 552 (Size: 4):
# Top Keywords: kompetensi, teknis, uji, pelatihan, bimbingan
# Sample Purposes:
# - mengikuti pelatihan pelaksanaan bimbingan teknis uji kompetensi minggu kegiatan tunda
# - izin ujian kompetensi kominfo it del pelatihan
# - pemanggilan bimbingan teknis uji kompetensi
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 553 (Size: 2):
# Top Keywords: penuh, menambah, ssd, laptop, yg
# Sample Purposes:
# - menambah ssd laptop penuh
# - menambah ssd laptop yg penuh mata kuliah pam
# Potential Business Opportunities:
# - Laptop Sales and Service
# - Computer Repair Shop
# - Tech Accessory Store
# - General Business Opportunities
#
# Cluster 554 (Size: 4):
# Top Keywords: bul, delcha, membersihkan, sekitaran, proyek
# Sample Purposes:
# - proyek delcha pantai bul bul
# - proyek delcha membersihkan sekitaran danau toba
# - proyek delcha membersihkan sekitaran lumban bul bul
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 555 (Size: 6):
# Top Keywords: delcha, proyek, melaksanakan, tugas, keperluan
# Sample Purposes:
# - keperluan proyek delcha
# - melaksanakan proyek delcha
# - proyek delcha
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 556 (Size: 4):
# Top Keywords: giving, character, proyek, del, delcha
# Sample Purposes:
# - proyek giving back del character
# - melaksanakan proyek delcha giving back program
# - melaksanakan proyek delcha giving back eksternal
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 557 (Size: 6):
# Top Keywords: requirement, pa, proyek, keperluan, kantin
# Sample Purposes:
# - requirement keperluan proyek
# - requirement
# - requirement pa
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 558 (Size: 5):
# Top Keywords: merapikan, rambut, seminar, laguboti, uas
# Sample Purposes:
# - merapikan rambut
# - persiapan uas merapikan rambut
# - merapikan rambut balige
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 559 (Size: 5):
# Top Keywords: progres, smpn, pa, balige, smp
# Sample Purposes:
# - hasil progres pa smp n balige
# - izin menunjukan progres pembangunan website smp n laguboti tugas proyek
# - pa smpn balige
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 560 (Size: 4):
# Top Keywords: pengambilan, buku, tabungan, aktivasi, kip
# Sample Purposes:
# - aktivasi pengambilan buku rekening kip kuliah bni balige
# - konfirmasi dishub toba pengambilan data tatap muka
# - perbaiki buku tabungan bank mandiri
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 561 (Size: 2):
# Top Keywords: mengajar, delcha, tugas, sd, memenuhi
# Sample Purposes:
# - tugas delcha mengajar
# - memenuhi tugas delcha mengajar sd n marom
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 562 (Size: 6):
# Top Keywords: cepat, pemilu, pulang, ib, keperluan
# Sample Purposes:
# - cepat pulang pemilu
# - pulang kerumah cepat rumah keperluan pemilu
# - pulang cepat pemilu
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 563 (Size: 8):
# Top Keywords: silaen, smpn, pengerjaan, proyek, gathering
# Sample Purposes:
# - pengerjaan proyek smpn silaen persetujuan institusisekolah
# - requirement gathering smp n silaen
# - requirement gathering smp negeri silaen
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 564 (Size: 2):
# Top Keywords: brimo, atm, mengurus, kartu, kawan
# Sample Purposes:
# - mengurus atm brimo
# - mengurus brimo kartu atm
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 565 (Size: 2):
# Top Keywords: ngurus, pangkas, rusak, hp, atm
# Sample Purposes:
# - ngurus atm mobile banking pangkas
# - ngurus hp rusak
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 566 (Size: 2):
# Top Keywords: mutiara, sd, requirement, balige, proyek
# Sample Purposes:
# - requirement sd mutiara balige keperluan pa
# - requirement proyek i sd swasta mutiara balige
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 567 (Size: 3):
# Top Keywords: senin, dokter, meninggal, jam, bapa
# Sample Purposes:
# - kontrol behel porsea janji dokter senin mata kuliah senin jam jam
# - orang meninggal bapa tua meninggal selesai uas senin
# - senin dokter dirujuk poli bedah
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 568 (Size: 8):
# Top Keywords: kebutuhan, pa, pengumpulan, requirement, proyek
# Sample Purposes:
# - memenuhi kebutuhan perkuliahan
# - pengumpulan informasi kebutuhan sekolah kebutuhan proyek mata kuliah pa bertempatan smpn laguboti
# - wawancara ll kebutuhan pa
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 569 (Size: 3):
# Top Keywords: lapangan, proyek, pembimbing, mariana, simanjuntak
# Sample Purposes:
# - proyek lapangan mata kuliah delcha dosen pembimbing mariana simanjuntak
# - proyek kerja lapangan mata kuliah delcha dosen pembimbing mariana simanjuntak
# - survei lapangan proyek ahir
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 570 (Size: 3):
# Top Keywords: engineering, laguboti, smp, requirement, pa
# Sample Purposes:
# - requirement engineering mata kuliah pa smp laguboti
# - requirement engineering smpn laguboti
# - requement engineering matakuliah pa smp laguboti
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 571 (Size: 7):
# Top Keywords: pengobatan, gigi, mata, gatal, membawa
# Sample Purposes:
# - pengobatan mata
# - membawa orangtua pengobatan
# - pengobatan gigi
# Potential Business Opportunities:
# - Klinik Gigi Spesialis Ortodonti
# - Produk Perawatan Gigi Tambahan
# - Layanan Konsultasi Online
# - General Business Opportunities
#
# Cluster 572 (Size: 2):
# Top Keywords: nomor, mengurus, handphone, online, hilang
# Sample Purposes:
# - mengurus atm mengganti nomor hp tertaut rekening online
# - mengurus kartu identitas nomor handphone hilang
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 573 (Size: 5):
# Top Keywords: sekolah, tugas, pa, wawancara, kelompok
# Sample Purposes:
# - tugas kelompok pa sekolah
# - pulang rumah acara gereja sekolah minggu
# - keperluan izin paiii rangaka mengumpulkan data requirement gathering sekolah smksma sekitaran laguboti
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 574 (Size: 5):
# Top Keywords: gigi, mengurus, kerumah, keperluan, pulang
# Sample Purposes:
# - pulang kerumah menambal gigi
# - dokter gigi dicabut gigi balige apotik gigi
# - meriksa gigi
# Potential Business Opportunities:
# - Klinik Gigi Spesialis Ortodonti
# - Produk Perawatan Gigi Tambahan
# - Layanan Konsultasi Online
# - General Business Opportunities
#
# Cluster 575 (Size: 3):
# Top Keywords: validasi, data, mvp, kebutuhan, tugas
# Sample Purposes:
# - validasi mvp kebutuhan stupen
# - bertemu orang tua validasi data keperluan tugas
# - validasi data
# Potential Business Opportunities:
# - Academic Support
# - Project Management
# - Consulting Services
# - General Business Opportunities
#
# Cluster 576 (Size: 2):
# Top Keywords: ukm, wawancara, del, kegiatan, dataset
# Sample Purposes:
# - kegiatan ukm rdc radio del fm
# - wawancara warga analasis keperluan dataset tugas wawancara ukm toba
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 577 (Size: 5):
# Top Keywords: kawat, gigi, kontrol, lepas, menemui
# Sample Purposes:
# - dokter gigi kawat behel lepas balige
# - menemui orang tua kontrol kawat gigi
# - ib kontrol kawat gigi
# Potential Business Opportunities:
# - Klinik Gigi Spesialis Ortodonti
# - Produk Perawatan Gigi Tambahan
# - Layanan Konsultasi Online
# - General Business Opportunities
#
# Cluster 578 (Size: 5):
# Top Keywords: kemalaman, mempercepat, kepulangan, rumah, ib
# Sample Purposes:
# - ujian selesai pulang kemalaman
# - pulang libur paskah rumah rumah kemalaman
# - mempercepat izin bermalam wisuda abang kemalaman perginya
# Potential Business Opportunities:
# - Travel Accommodation
# - Home Services
# - Family Support
# - General Business Opportunities
#
# Cluster 579 (Size: 2):
# Top Keywords: diskusi, progres, sekolah, client, kuliah
# Sample Purposes:
# - izin diskusi progres pa client
# - diskusi sekolah keperluan mata kuliah proyek i
# Potential Business Opportunities:
# - General Business Opportunities
#
# Cluster 580 (Size: 5):
# Top Keywords: besok, kepulangan, mempercepat, ib, pemilu
# Sample Purposes:
# - mempercepat kepulangan ib
# - mempercepat kepulangan ib besok pemilu rumah
# - balige membeli bunga ibadah jumat besok
# Potential Business Opportunities:
# - General Business Opportunities
